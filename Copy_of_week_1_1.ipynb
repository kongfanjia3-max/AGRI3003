# %% [markdown]
# <a href="https://colab.research.google.com/github/kongfanjia3-max/AGRI3003/blob/AGRI3003-branch/Copy_of_week_1_1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Python programs
#
# This is an introductory lab where you will run a Python program to create an AI-powered farm management chat assistant using a <a href="https://stanford-cs324.github.io/winter2022/lectures/introduction/" target="_blank">language model</a>.
#
# The goal of this lab is to provide a brief introduction to the Python programming language; demonstrate some programming concepts such as data types, data structures, and functions; and to illustrate why programming is a useful skill for solving problems and implementing data-driven solutions.
#
# ## A Python program
#
# * A program is a series of statements that are executed to complete a task
# * Here, the statements are written using the syntax of the Python programming language
# * Programs complete tasks by loading, transforming, and visualising data
# * Data in programs can be of different types (numeric, text, boolean)
# * Data can be combined into data structures to represent complex concepts and objects
# * Functions operate on data to complete tasks
#
# ### Run the labs
#
# You can run the labs locally on your machine or you can use cloud environments provided by Google Colab. **If you're working with Google Colab be aware that your sessions are temporary and you'll need to take care to save, backup, and download your work.**
#
# <a href="https://colab.research.google.com/github/geog3300-agri3003/coursebook/blob/main/docs/notebooks/week-1_1.ipynb" target="_blank">
#   <img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/>
# </a>

# %% [markdown]
# ## Setup
#
# ### Setup Hugging Face token
#
# 1. Create a Hugging Face account:
#
# <img src="https://github.com/geog3300-agri3003/coursebook/raw/main/docs/img/hf-1-annotated.png" alt="HF account" width="75%">
#
# Once, you have created a Hugging Face account you can gain access to models. Many LLMs require you accept terms and conditions. For this exercise we will be working with Google's Gemma 2 2b it model (2b represents 2 billion parameters and it represents instruction tuned). Agree to the model's terms and conditions and usage policy <a href="https://huggingface.co/google/gemma-2-2b-it" target="_blank">here</a>.
#
# 2. Create an *Access Token*:
#
# <img src="https://github.com/geog3300-agri3003/coursebook/raw/main/docs/img/hf-2-annotated.png" alt="HF account" width="75%">
#
# 3. Click on *Create new token*
#
# <img src="https://github.com/geog3300-agri3003/coursebook/raw/main/docs/img/hf-3-annotated.png" alt="HF account" width="75%">
#
# 4. Set the token permissions
#
# You can initially set token permissions to *Read*, which has read access to all your resources. This is a good option for getting started.
#
# <img src="https://github.com/geog3300-agri3003/coursebook/raw/main/docs/img/hf-4-read-annotated.png" alt="HF account" width="75%">
#
# However, as you start developing resources such as models and datasets and using Hugging Face in different environments, it's a good idea to create access tokens with fine-grained permissions with just enough permissions to complete tasks associated with the token. If you set fine-grained permissions, you should check the box *Read access to contents of all public gated repos you can access* to work with the Gemma models in these examples.
#
# <img src="https://github.com/geog3300-agri3003/coursebook/raw/main/docs/img/hf-4-annotated.png" alt="HF account" width="75%">
#
# If you have selected fine-grained permissions, you will need to add repositories (models) that you want that token to grant permission to. You will need to check the boxes *Read access to contents of selected repos* and *View access to contensts of selected repos*.
#
# <img src="https://github.com/geog3300-agri3003/coursebook/raw/main/docs/img/hf-5-annotated.png" alt="HF account" width="75%">
#
# 6. Click *Create token* to generate the access token.
#
# <img src="https://github.com/geog3300-agri3003/coursebook/raw/main/docs/img/hf-6-annotated.png" alt="HF account" width="75%">
#
# 7. Copy the access token. **This is your only opportunity to do this - keep a record of the token (in a secure location)**. If you lose your token, it's easy to generate a new one.
#
# <img src="https://github.com/geog3300-agri3003/coursebook/raw/main/docs/img/hf-7-annotated.png" alt="HF account" width="75%">
#
# 8. In Google Colab, click on the *key* icon in the left-hand sidebar.
#
# <img src="https://github.com/geog3300-agri3003/coursebook/raw/main/docs/img/hf-8-annotated.png" alt="HF account" width="75%">
#
# 9. Add your Hugging Face access token with the name `HF_TOKEN` and make sure the Notebook access it checked. **Restart your Google Colab session to load the token into your environment**.
#
# <img src="https://github.com/geog3300-agri3003/coursebook/raw/main/docs/img/hf-9-annotated.png" alt="HF account" width="50%">
#
# ### Setup runtime
#
# **This lab will only work (quickly) using Google Colab with a *T4 GPU* runtime type.**
#
# **Before running any code, set the runtime type to *T4 GPU*.**
#
# <img src="https://github.com/geog3300-agri3003/coursebook/raw/main/docs/img/week-1-colab-runtime-1.jpg" alt="colab runtime menu" width="50%">
#
# <p></p>
#
# <img src="https://github.com/geog3300-agri3003/coursebook/raw/main/docs/img/week-1-colab-runtime-2.jpg" alt="colab runtime menu" width="50%">

# %% [markdown]
# ### Import modules
#
# A package is a collection of files containing Python code that we can use in our program. Files containing Python code are called modules (a package is a collection of modules). By importing Python packages, we can make our programs shorter and reuse code that has already been written to complete a task.
#
# For example, the pandas provides a DataFrame structure for storing tabular data and specific functions for working with tabular data.
#
# We need to immport the modules into our Python program where they can be used.
#
# Here, we import a package called `os`, which contains tools for working with the operating system (e.g. creating paths to folders and files).
#
# We also import `torch` and `transformers`, which are machine learning packages.
#
# Importing these packages into our program means we can re-use code that has already been written to work with deep learning models that can receive and generate natural language. We'll use these tools in our program to create an AI farm chat assistant.

# %%
import os
import torch
from transformers import pipeline

# %% [markdown]
# ## Using `pipeline` objects
#
# To create a `pipeline` object call the `pipeline()` instantiator function as pass in the task (`"text-generation"` here), the model (`"google/gemma-2-2b-it"`), and some additional arguments. Set the `device_map` argument to `"auto"` to run the model on Colab's GPU when it is available.
#
# An object in Python programs is a container for related data and functions. Data is information related to a particular concept, represented by the object, and functions do things with data to complete a task.
#
# This will download the model to your Colab environment, which will take a moment or two. Here, we are using <a href="https://huggingface.co/google/gemma-2-2b-it" target="_blank">Google's Gemma 2 2b it model</a> - follow this link to make yourself aware of the terms of use for this model.

# %%
pipe = pipeline(
    "text-generation",
    model="google/gemma-2-2b-it",
    model_kwargs={"torch_dtype": torch.bfloat16},
    device_map="auto",
)
# Out:
# config.json:   0%|          | 0.00/838 [00:00<?, ?B/s]
# `torch_dtype` is deprecated! Use `dtype` instead!
# `torch_dtype` is deprecated! Use `dtype` instead!
# model.safetensors.index.json:   0%|          | 0.00/24.2k [00:00<?, ?B/s]
# Downloading (incomplete total...): 0.00B [00:00, ?B/s]
# Fetching 2 files:   0%|          | 0/2 [00:00<?, ?it/s]
# Loading weights:   0%|          | 0/288 [00:00<?, ?it/s]
# generation_config.json:   0%|          | 0.00/187 [00:00<?, ?B/s]
# tokenizer_config.json:   0%|          | 0.00/47.0k [00:00<?, ?B/s]
# tokenizer.json:   0%|          | 0.00/17.5M [00:00<?, ?B/s]
# special_tokens_map.json:   0%|          | 0.00/636 [00:00<?, ?B/s]

# %% [markdown]
# ## Functions
#
# Our `pipe` object can be treated as a function. You can spot functions by `()` appearing after the function name. Functions can take input data - this is the function's arguments -  and use these inputs to complete it's task.
#
# Functions can return data back to the Python program, display data on your screen, or save data to disk.
#
# The general pattern for executing a function / method is:
#
# 1. The function is called and any data are passed in as arguments inside `()`
# 2. The function performs operations on the data passed in
# 3. The function returns the result of operating on the data
#
# The `pipe()` function takes in text data as a prompt (here we ask `"What is canola?"`) and a number to the `max_new_tokens` paramter.
#
# It returns the output text that the Gemma model has generated in response to the prompt. This output text is referenced by the variable `output`.
#
# **The <a href="https://blog.google/technology/developers/gemma-open-models/">Gemma</a> model we are using is a reduced size and open large language model. Therefore, its responses might not be as accurate as ones generated from larger models available online (e.g. Gemini or ChatGPT). We would probably not use this version of the Gemma model directly in a agricultural chat assistant; we would fine-tune or train a LLM to be more accurate with agricultural topics. However, it is a good example of how we can use Python to build a program to provide a useful service or solve a task. In this case, we're building a program that would let people use AI to get more information about farm management.**
#
# **It is also your responsibility to only provide agriculturally relevant prompts to the model. You should not create offensive, personal, or controversial prompts. This is also a more general principle when working with big datasets, machine learning models and when developing technology. It is important to do so in a way that causes no harm.**

# %%
prompt = "What is canola?"

outputs = pipe(prompt, max_new_tokens=512)
response = outputs[0]["generated_text"].strip()
print(response)
# Out:
# Passing `generation_config` together with generation-related arguments=({'max_new_tokens'}) is deprecated and will be removed in future versions. Please pass either a `generation_config` object OR all generation parameters explicitly, but not both.
# Both `max_new_tokens` (=512) and `max_length`(=20) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
# What is canola?
#
# Canola is a type of oilseed crop that is a member of the mustard family, Brassicaceae. It's often called rapeseed in other countries, but it's the same plant.
#
# Here's a breakdown:
#
# **Origins:**
# - Cultivated for centuries in Asia, Europe, and North America, where it's known for its high oil content.
# -  It was introduced to Canada in the mid-1800s.
#
# **Key Features:**
# - **Oil-rich seeds:** Canola seeds have a high proportion of oil, making them a valuable source of energy and a component of many foods.
# - **Low in erucic acid:** Canola is known for having low levels of erucic acid, a compound found in some other rapeseed varieties, which can cause health issues.
# - **Cold-resistant:** This allows canola to thrive in different climates, including areas with colder winters.
# - **Versatile:** The oil extracted from canola can be used for cooking, flavoring, and even biodiesel production.
#
#
# **Uses:**
# - **Cooking oil:** Canola oil is a popular choice for cooking due to its mild flavor and high smoke point.
# - **Food products:** Canola is used in various food products, including margarine, salad dressings, bakery products, and processed snacks.
# - **Biodiesel:** Canola oil can be used to produce biodiesel, a renewable energy source.
# - **Animal feed:** Canola meal is a valuable source of nutrients for livestock and poultry.
#
#
#
# Overall, canola is a versatile and valuable crop with a range of uses. It plays a crucial role in the food, fuel, and agricultural industries.

# %% [markdown]
# #### Recap quiz
#
# <details>
#     <summary><b>Is <code>print()</code> a function?</b></summary>
#
# Yes, `print()` is a function. You can tell it's a function because of the parentheses after the function name. The fact that print is a verb also indicates it's a function - something is being done (nouns are often used to indicate data). `print()` takes in data from our Python program and prints a representation of this data on our display. Above, we pass in the output from generating text with our Gemma model and print it on the display.
# </details>

# %% [markdown]
# ## Data
#
# Programs generally complete their tasks by doing things with data. Data can be scientific data which can be analysed and visualised. However, in a computer program data refers to any information the program needs to run. For example, it could be text data such as file paths or file names or URLs for resources on the internet.
#
# There are different types of data. Python provides support for the following built-in data types:
#
# * `float` - storing floating point numeric values.
# * `int` - storing integer numeric values.
# * `str` - storing text data as strings.
# * `bool` - storing True or False as boolean values.
# * `None` - storing null values.
# * `bytes` - storing raw binary data.
#
# Our AI-powered farm assistant program requires two key pieces of data. Text prompts for the user (i.e. questions or requests for information) and text outputs from the LLM. Here, we'll be storing text data as <a href="https://realpython.com/python-strings/" target="_blank">string (`str`)</a> type data in our program.
#
# In Python, we create `str` type data by placing text inside quotation marks `"a string"`.
#
# Let's create some different text prompts as `str` type data.

# %%
prompt = "Drought is affecting my wheat crop. What strategies can I use to protect crop yields?"

outputs = pipe(prompt, max_new_tokens=512)
response = outputs[0]["generated_text"].strip()
print(response)
# Out:
# Both `max_new_tokens` (=512) and `max_length`(=20) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
# Drought is affecting my wheat crop. What strategies can I use to protect crop yields?
#
# Here's some information about your situation:
#
# * **Location:**  [Provide your location. This will help me suggest region-specific strategies.]
# * **Stage of Crop:** [How much time has passed since planting? (Early stage, mid-stage, late stage)]
# * **Soil Type:** [What type of soil do you have? (Clay, Sandy, loamy)]
# * **Water Availability:** [How much available water do you have (e.g., irrigation access, rainfall)?]
#
# Once you provide me with this information, I can give you tailored advice on the following:
#
# * **Irrigation strategies:**  Whether to irrigate, how frequently, and how much water to apply.
# * **Weed management:** How to prevent weed competition for water and nutrients.
# * **Mulching:** Using mulch to conserve moisture and soil temperature.
# * **Nitrogen management:** How to optimize nitrogen fertilization for drought tolerance.
# * **Pest and disease control:**  Implementing preventive measures against drought-related pests and diseases.
# * **Harvesting strategies:**  Determining the best time to harvest your wheat crop.
#
#
# Let's work together to protect your wheat crop!

# %% [markdown]
# #### Recap quiz
#
# **Can you create a new prompt of `str` type data to ask the model about pests affecting bananas?**

# %%
prompt = "How pests affecting bananas?"

outputs = pipe(prompt, max_new_tokens=512)
response = outputs[0]["generated_text"].strip()
print(response)
# Out:
# Both `max_new_tokens` (=512) and `max_length`(=20) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
# How pests affecting bananas?
#
# Bananas are a highly susceptible crop to various pests, which can lead to significant yield losses and economic damage. Here's a breakdown of the most common banana pests:
#
# **1.  Fungal Pests:**
#
# * **Panama disease (Fusarium oxysporum f. sp. cubense):** This devastating fungal disease attacks the roots and vascular system of banana plants, causing wilting, yellowing, and ultimately plant death.
# * **Black Sigatoka (Mycosphaerella fijiensis):** This fungal disease causes large, dark brown spots on banana leaves, reducing photosynthesis and causing leaf drop.
#
# **2.  Insect Pests:**
#
# * **Banana weevil (Cosmopolites sordidus):** This weevil bores into banana plants, causing extensive damage to the roots and stems, leading to plant death.
# * **Banana aphid (Aphis gossypii):** This aphid feeds on banana plants, causing stunted growth, yellowing, and eventually, plant decline.
# * **Banana thrips (Scirtothrips dorsalis):** This thrips feeds on young banana leaves, causing damage to the leaves and reducing their productivity.
# * **Banana stem borer (Chilo infuscatellus):** This moth lays eggs on banana plants, and the larvae burrow into the stems, causing severe damage and plant death.
# * **Whiteflies (Bemisia tabaci):** These white, winged insects feed on banana plants, causing leaf yellowing and stunting.
# * **Leaf miners (Liriomyza spp.):** These flies lay eggs under the surface of banana leaves, burrowing into the leaves and causing damage.
#
# **3.  Other Pests:**
#
# * **Rodents:** Rats and mice can damage banana plants and contaminate their storage.
# * **Birds:** Birds can peck at banana plants and cause significant damage.
# * **Snails:** Some snails can feed on banana leaves and damage the plants.
#
#
# **Impact on Banana Production:**
#
# These pests can significantly impact banana production in several ways:
#
# * **Yield Loss:** Pests can cause substantial damage to banana crops, leading to reduced yields and profitability.
# * **Quality Deterioration:** Pests can also affect the quality of bananas, making them less desirable for consumers.
# * **Economic Impact:** The damage caused by pests can significantly impact the livelihoods of farmers and the banana industry.
#
#
# **Control Measures:**
#
# Several control measures can be employed to manage banana pests and protect banana crops. These include:

# %% [markdown]
# <details>
#     <summary><b>answer</b></summary>
#
# ```python
# prompt = "What insects and pests affect banana crops?"
#
# outputs = pipe(prompt, max_new_tokens=512)
# response = outputs[0]["generated_text"].strip()
# print(response)
# ```
# </details>

# %% [markdown]
# ## Data structures
#
# Python provides a series of built-in data structures that can be used to group together and store related data.
#
# You can think of a data structure as a container for related data values in a Python program. For example, a DataFrame is often used to store a tabular datset similar to how you would store data in a spreadsheet in excel.
#
# A commonly used data structure in Python is a `list`. A `list` stores .... a list of data values.
#
# A Python `list` is created by placing data values inside square brackets `[]`. If we have many prompts or questions we want to ask out farm assistant, we can store them all in a list.

# %%
prompts = [
    "When are wheat crops ready for harvest in Western Australia?",
    "What is harvest weed seed control?",
]

# %% [markdown]
# `prompts` is a list of two elements. Each element is a prompt for our LLM of `str` type data. Elements in a Python `list` have an index position starting at 0 for the first element. We can access elements of a list using their index. For example, to access the second element of the list we would execute the following statement:
#
# `prompts[1]`
#
# Note that index position 1 corresponds to the second element. Indexing starts at 0.

# %%
print(f"the first element in the list is {prompts[0]}")
print(f"the second element in the list is {prompts[1]}")
# Out:
# the first element in the list is When are wheat crops ready for harvest in Western Australia?
# the second element in the list is What is harvest weed seed control?

# %% [markdown]
# We can add items to our list using a `list` object's `append()` method. Note, this is a function as you can see the `()` after append.
#
# To use the `append()` method, we pass in the data we wish to append to the end of the list. Let's add another prompt to our list: `"What herbicides are used in Australia?"`

# %%
prompts.append("What herbicides are used in Western Australia?")
print(prompts)
# Out:
# ['When are wheat crops ready for harvest in Western Australia?', 'What is harvest weed seed control?', 'What herbicides are used in Western Australia?']

# %% [markdown]
# #### Recap quiz
#
# **Can you add another item to `prompts`? The item to add is `"What grain crops are grown in France?"`.**

# %%
## ADD CODE HERE

# %% [markdown]
# <details>
#     <summary><b>answer</b></summary>
#
# ```python
# prompts.append("What grain crops are grown in France?")
# prompts
# ```
# </details>

# %% [markdown]
# ## Flow control
#
# Flow control refers to the order in which the statements that make up a program are executed. A common flow control tool are a for loops. For loops allow us to iterate over items in a sequence; we can loop over items in a list. To loop over the items in `prompts` and print the current item we would execute:

# %%
for p in prompts:
    print(p)
# Out:
# When are wheat crops ready for harvest in Western Australia?
# What is harvest weed seed control?
# What herbicides are used in Western Australia?

# %% [markdown]
# ## Putting it all together: a Python program
#
# Now we can put together the various concepts we've covered above (data types, data structures, functions, and flow control) to create a simple program that can store multiple prompts or questions from a user, pass these prompts into our LLM, and return answers.
#
# This is a basic template of Python program to create an AI-powered farm chat assistant app. If we were expanding this we might build a user interface (e.g. a web form) where users could enter prompts that would be added to the `prompts`. We should also use a model that is trained and tested for the application domain we're working in. However, this is a small illustration of how to write a Python program to complete a task (in this case building a small prototype application for a farm chat assistant).

# %%
for p in prompts:
    print("Question for the farm assistant:")
    outputs = pipe(p, max_new_tokens=512)
    response = outputs[0]["generated_text"].strip()
    print(response)
    print("")
    print("***************")
    print("")
# Out:
# Both `max_new_tokens` (=512) and `max_length`(=20) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
# Question for the farm assistant:
# Both `max_new_tokens` (=512) and `max_length`(=20) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
# When are wheat crops ready for harvest in Western Australia?
#
# It's a bit complicated, so let's break it down:
#
# * **Harvest Time:** Wheat crops in Western Australia typically reach maturity between **April and December**, depending on the specific variety and growing conditions.
# * **Early Varieties:** Some faster-growing varieties can be harvested in as early as **late March to early April**.
# * **Later Varieties:**  Slow-maturing varieties may not be ready for harvest until **November or December**.
# * **Weather:**  Rainfall and temperature play a huge role.  Drought can delay ripening, while cooler temperatures can extend harvest time.
#
# **Key Takeaways:**
#
# * **Harvest timing varies widely.** It's not a single date across the entire state.
# * **Early varieties are harvested first.**
# * **Weather conditions are critical.**
#
#
# If you're looking for more specific information about a particular farm or location, the best resource is to contact the WA Department of Primary Industries and Regional Development or a local agricultural expert.
#
# ***************
#
# Question for the farm assistant:
# Both `max_new_tokens` (=512) and `max_length`(=20) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
# What is harvest weed seed control?
#
# Harvest weed seed control is a method of weed control that focuses on **removing and destroying weed seeds from the harvested crop**, rather than targeting weeds during the growing season.
#
# **Here's how it works:**
#
# * **Harvest**: The crop is harvested, typically with a combine harvester.
# * **Seed Treatment**: The harvested crop is then treated to remove or destroy weed seeds. This treatment is usually done using heat, chemicals, or a combination of both.
# * **Residue Management**: The residue from the harvested crop is managed to ensure that weed seeds are not spread. This can involve burning, rolling, or chopping.
#
# **Benefits of Harvest Weed Seed Control:**
#
# * **Reduced Seedling Establishment:** This method effectively prevents weed seeds from germinating in the following growing season, reducing competition for resources.
# * **Reduced Herbicide Use:** By removing weed seeds, the need for herbicides can be reduced or eliminated.
# * **Enhanced Crop Yield:** Reduced competition and cleaner growing conditions can contribute to higher crop yields.
# * **Improved Soil Health:** By managing the weed seed bank, this method can help contribute to long-term soil health.
#
# **However, there are also some potential drawbacks:**
#
# * **Cost**: The cost of implementing harvest weed seed control can be high, especially for large-scale operations.
# * **Limited Effectiveness**: It may not be effective for all weeds and may require careful planning and management.
# * **Environmental Considerations**: Some treatments might have negative environmental impacts, so it is important to consider these carefully.
#
# **Overall, harvest weed seed control is a viable method for weed management, but it's essential to consider the pros and cons before implementing it.**
#
# It's worth noting that there are several methods for treating weed seeds, including:
#
# * **Heat treatment**: Heat can kill weed seed viability.
# * **Chemical treatment**: Certain chemicals can be used to destroy weed seeds.
# * **Mechanical treatment**: This involves physically destroying weed seeds, such as using a threshing machine.
#
# The choice of treatment method depends on several factors, including the type of weed, the crop, and the budget.
#
# ***************
#
# Question for the farm assistant:
# What herbicides are used in Western Australia?
#
# While I can't provide specific product recommendations, here's a general overview of the common herbicide classes used in Western Australia, along with some important considerations:
#
# **Herbicide Classes in Western Australia:**
#
# * **Selective Herbicides (Targeted to Specific Weeds):** These herbicides kill targeted weeds while leaving desired crops and plants unharmed. Examples include:
#     * **Photosystem II Inhibitors:** These herbicides disrupt photosynthesis and are effective against broadleaf weeds.
#     * **Dicamba:** Used for broadleaf weed control, but has strict application restrictions in Western Australia.
#     * **Imazapyr:** A pre-emergent herbicide effective for controlling a wide range of weeds.
#
# * **Non-Selective Herbicides (Broad-Spectrum Weed Control):** These herbicides kill almost all types of plants, including weeds and crops. Examples include:
#     * **Glyphosate:** One of the most widely used herbicides globally, effective against a broad range of weeds.
#
# * **Residual Herbicides:** These herbicides provide long-lasting weed control by inhibiting weed growth even after application.  Examples include:
#     * **Atrazine:** Can be effective for controlling broadleaf weeds.
#
# **Key Considerations:**
#
# * **Weed Identification:** It's crucial to correctly identify your weeds before using any herbicide. This ensures you're targeting the correct species and avoiding potential harm to desirable plants.
# * **Application Timing:** The timing of herbicide application can drastically influence its effectiveness. Consult product labels and local experts for optimal application windows.
# * **Environmental Impact:**  Remember that herbicides can impact the environment. Always follow recommended safety precautions, store your products properly, and consider responsible disposal methods.
# * **Soil Conditions:** Soil type, pH, and moisture can affect herbicide effectiveness. Consider these factors when choosing and applying herbicides.
# * **Local Regulations:** Always adhere to local regulations and restrictions regarding the use of herbicides in Western Australia.
#
# **Where to Seek More Information:**
#
# * **Department of Agriculture and Food Western Australia (DAFWA):** The DAFWA website offers extensive information on weeds, herbicides, and agricultural practices in Western Australia.
# * **Local Agricultural Extension Services:** These services provide personalized advice and technical guidance for specific regions and agricultural needs.
# * **Seed and Chemical Distributors:** Local distributors can answer specific questions about the types of herbicides available in your area.
#
#
# **Remember:** Using herbicides safely and responsibly is essential for protecting the environment, your health, and the success of your agricultural goals
#
# ***************
